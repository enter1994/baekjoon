# %%
T = int(input())

for i in range(T):    
    # h : 호텔의 층수 w : 각층의 방수 n : 몇번째 손님
    h, w, n = map(int, input().split())
    
    if floor == 0:
        floor = h
        num = n//h
    else:
        floor = n%h
        num = n//h + 1 
    
    print(floor*100 + num)
